# %%
from PIL import Image
import matplotlib.pyplot as plt
imagen = Image.open('Batman.jpg').convert('RGB')
imagen2 = Image.open('BugsBonny.jpg').convert('RGB')
imagen3= Image.open('capitan_america.jpg').convert('RGB')
imagen4 = Image.open('Correcaminos.jpg').convert('RGB')
imagen5 = Image.open('Coyote.jpg').convert('RGB')
imagen6 = Image.open('Demonio_de_tazmania.jpg').convert('RGB')
imagen7 = Image.open('Flash.jpg').convert('RGB')
imagen8 = Image.open('HombreAraña.jpg').convert('RGB')
imagen9 = Image.open('Hulk.jpg').convert('RGB')
imagen10 = Image.open('Mujer_Maravilla.jpg').convert('RGB')
imagen11= Image.open('Pato_Luca.jpg').convert('RGB')
imagen12 = Image.open('Silvestre.jpg').convert('RGB')
imagen13 = Image.open('Superman.jpg').convert('RGB')
imagen14 = Image.open('Tweety.jpg').convert('RGB')
#print (imagen.size)

# %%
imagen.show()

# %%
r, g, b = imagen.split()

# %%
r1 = r.point(lambda i: i * 1) #rojo
g1 = g.point(lambda i: i * 0)
b1 = b.point(lambda i: i * 0)

# %%
r2 = r.point(lambda i: i * 0.1) 
g2 = g.point(lambda i: i * 0.1)
b2 = b.point(lambda i: i * 1) #azul

# %%
r3 = r.point(lambda i: i * 0)
g3 = g.point(lambda i: i * 1)
b3 = b.point(lambda i: i * 0) #verde

# %%
r4 = r.point(lambda i: i * 1)
g4 = g.point(lambda i: i * 1)
b4 = b.point(lambda i: i * 0) #amarillento

# %%
r5 = r.point(lambda i: i * 1)
g5 = g.point(lambda i: i * 0)
b5 = b.point(lambda i: i * 0.8) #fucsia

# %%
resultado1 = Image.merge('RGB', (r1, g1, b1))
resultado2 = Image.merge('RGB', (r2, g2, b2))
resultado3 = Image.merge('RGB', (r3, g3, b3))
resultado4 = Image.merge('RGB', (r4, g4, b4))
resultado5 = Image.merge('RGB', (r5, g5, b5))

resultado1.save('pruebarojo.jpg')

print (resultado1.size)
# Out:
# (600, 600)

# %% [markdown]
# resultado1.show()
# resultado2.show()
# resultado3.show()
# resultado4.show()
# resultado5.show()

# %%
print("dimensiones de la componente roja (monocroma) =")
plt.imshow(resultado1, cmap='gray')
plt.title('componente rojo')
plt.show()

print("dimensiones de la componente roja (monocroma) =")
plt.imshow(resultado2, cmap='gray')
plt.title('componente rojo')
plt.show()

print("dimensiones de la componente roja (monocroma) =")
plt.imshow(resultado3, cmap='gray')
plt.title('componente rojo')
plt.show()

print("dimensiones de la componente roja (monocroma) =")
plt.imshow(resultado4, cmap='gray')
plt.title('componente rojo')
plt.show()

!
print("dimensiones de la componente roja (monocroma) =")
plt.imshow(resultado5, cmap='gray')
plt.title('componente rojo')
plt.show()
# Out:
# dimensiones de la componente roja (monocroma) =
# dimensiones de la componente roja (monocroma) =
# dimensiones de la componente roja (monocroma) =
# dimensiones de la componente roja (monocroma) =
# dimensiones de la componente roja (monocroma) =
